# %%
import pandas

# %%
dwt1_file=pandas.read_csv("dwt1.csv")
dwt1_file.rename(columns={dwt1_file.columns[0]: "Disney World Tickets - 2024 Militaryicket"}, inplace=True)
dwt1_file.head(6)
# Out:
#    Disney World Tickets - 2024 Militaryicket  Ages 3+
# 0       4-Day Park Hopper Promotional Ticket  $365.00
# 1  4-Day Park Hopper Plus Promotional Ticket  $395.00
# 2       5-Day Park Hopper Promotional Ticket  $385.00
# 3  5-Day Park Hopper Plus Promotional Ticket  $415.00
# 4       6-Day Park Hopper Promotional Ticket  $399.75
# 5  6-Day Park Hopper Plus Promotional Ticket  $435.00

# %%
import pandas

# %%
dwt2_file=pandas.read_csv("dwt2.csv")
dwt2_file.rename(columns={dwt2_file.columns[0]: "Disney World Tickets - Annual Passes"}, inplace=True)
dwt2_file.head(5)
# Out:
#                 Disney World Tickets - Annual Passes  Adult 10+ Gate w/ Tax
# 0                                Disney Incredi-Pass  $1,494.00   $1,543.19
# 1  Disney Incredi-Pass with Water Park and Sports...  $1,596.00   $1,648.62
# 2  Disney Incredi-Pass with Disney PhotoPass Down...  $1,596.00   $1,648.62
# 3  Disney Incredi-Pass with Water Park and Sports...  $1,698.00   $1,754.06

# %%
import pandas

# %%
dwt3_file=pandas.read_csv("dwt3.csv")
dwt3_file.head(5)
# Out:
#                                          Annual Pass     Age 3+
# 0                Civilian Annual Disney Incredi-Pass  $1,543.19
# 1  Civilian Annual Disney Incredi-Pass plus Photo...  $1,648.62
# 2  Water Park and Sport Option Civilian Annual Di...  $1,754.06

# %%
import pandas

# %%
dwt4_file=pandas.read_csv("dwt4.csv")
dwt4_file.head(5)
# Out:
#       Disney Florida Resident Pixie Dust Annual Pass  Ages 3+
# 0                   Florida Resident Pixie Dust Pass  $452.75
# 1  Florida Resident Pixie Dust Pass w/ Water Park...  $554.75
# 2  Florida Resident Pixie Dust Pass w/ Disney Pho...  $554.75
# 3  Florida Resident Pixie Dust Pass w/ Water Park...  $656.75

# %%
import pandas

# %%
dwt5_file=pandas.read_csv("dwt5.csv")
dwt5_file.head(10)
# Out:
#              Epcot Adult 10+ Child (3-9)
# 0  February 2,2008   $146.25     $146.25
# 1        June 6,20   $146.25     $146.25
# 2          July 18   $146.25     $146.25
# 3      February 15   $156.00     $156.00
# 4       March 7,28   $156.00     $156.00
# 5       April 4,25   $156.00     $156.00
# 6      May 9,23,30   $156.00     $156.00

# %%
import pandas

# %%
dwt6_file=pandas.read_csv("dwt6.csv")
dwt6_file.head(5)
# Out:
#         Florida Resident Annual Passes - Pirate Pass   Adult 3+ Gate w/ Tax
# 0                     FL Resident Disney Pirate Pass    $824.00     $850.94
# 1  FL Resident Disney Pirate Pass with Water Park...    $926.00     $956.37
# 2  FL Resident Disney Pirate Pass with Disney Pho...    $926.00     $956.37
# 3  FL Resident Disney Pirate Pass with Water Park...  $1,028.00   $1,061.81

# %%
import pandas

# %%
dwt7_file=pandas.read_csv("dwt7.csv")
dwt7_file.head(5)
# Out:
#       Florida Resident Annual Passes - Sorcerer Pass   Adult 3+ Gate w/ Tax
# 0                   FL Resident Disney Sorcerer Pass  $1,030.00   $1,063.94
# 1  FL Resident Disney Sorcerer Pass with Water Pa...  $1,132.00   $1,169.37
# 2  FL Resident Disney Sorcerer Pass with Disney P...  $1,132.00   $1,169.37
# 3  FL Resident Disney Sorcerer Pass with Water Pa...  $1,234.00   $1,274.81

# %%
import pandas

# %%
dwt8_file=pandas.read_csv("dwt8.csv")
dwt8_file.head(5)
# Out:
#   Florida Resident Annual Passes - Exchange Certificates   Adult 3+  \
# 0                    FL Resident Disney Incredi-Pass      $1,494.00
# 1  FL Resident Disney Incredi-Pass with Water Par...      $1,596.00
# 2  FL Resident Disney Incredi-Pass with Disney Ph...      $1,596.00
# 3  FL Resident Disney Incredi-Pass with Water Par...      $1,698.00
#
#   Gate w/ Tax
# 0   $1,543.19
# 1   $1,648.62
# 2   $1,648.62
# 3   $1,754.06

# %%
import pandas

# %%
dwt9_file=pandas.read_csv("dwt9.csv")
dwt9_file.head(9)
# Out:
#             Florida Resident Disney Discover Tickets Adult 10+ Child (3-9)
# 0                              3-Day Disney Discover   $215.25     $215.25
# 1      3-Day Disney Discover with Park Hopper Option   $254.00     $254.00
# 2  3-Day Disney Discover with Water Park and Spor...   $249.25     $249.25
# 3  3-Day Disney Discover with Park Hopper Plus Op...   $268.50     $268.50
# 4                              4-Day Disney Discover   $230.75     $230.75
# 5      4-Day Disney Discover with Park Hopper Option   $269.50     $269.50
# 6  4-Day Disney Discover with Water Park and Spor...   $264.75     $264.75
# 7  4-Day Disney Discover with Park Hopper Plus Op...   $284.25     $284.25

# %%
import pandas

# %%
dwt10_file=pandas.read_csv("dwt10.csv")
dwt10_file.head(8)
# Out:
#               Florida Resident Disney Select Tickets Adult 10+ Child (3-9)
# 0                                3-Day Disney Select   $247.75     $238.00
# 1        3-Day Disney Select with Park Hopper Option   $285.00     $275.00
# 2  3-Day Disney Select with Water Park and Sports...   $282.50     $272.50
# 3   3-Day Disney Select with Park Hopper Plus Option   $294.75     $285.00
# 4                                4-Day Disney Select   $272.50     $261.75
# 5        4-Day Disney Select with Park Hopper Option   $314.75     $303.75
# 6  4-Day Disney Select with Water Park and Sports...   $307.25     $296.50
# 7   4-Day Disney Select with Park Hopper Plus Option   $324.50     $313.75

# %%
import pandas

# %%
dwt11_file=pandas.read_csv("dwt11.csv")
dwt11_file.head(5)
# Out:
#                     Florida Resident One Day Tickets Adult 10+ Child (3-9)
# 0  Florida Resident MYW 1-Day *Seasonal with Park...   $178.00     $173.00
# 1  Florida Resident MYW 1-Day *Seasonal with Park...   $193.75     $188.25
# 2  Florida Resident MYW 1-Day with Park Hopper Op...   $209.75     $204.25
# 3  Florida Resident MYW 1-Day with Park Hopper Pl...   $220.00     $214.75

# %%
import pandas

# %%
dwt12_file=pandas.read_csv("dwt12.csv")
dwt12_file.head(12)
# Out:
#    Hollywood Studios Adult 10+ Child (3-9)
# 0         January 10   $152.25     $152.25
# 1         July 24,31   $152.25     $152.25
# 2           August 7   $152.25     $152.25
# 3         January 24   $162.00     $162.00
# 4      June 12,19,26   $162.00     $162.00
# 5         July 10,17   $162.00     $162.00
# 6     February 21,26   $171.75     $171.75
# 7     March 13,20,27   $171.75     $171.75
# 8         April 3,10   $171.75     $171.75
# 9          May 22,29   $171.75     $171.75
# 10   August 14,21,29   $142.25     $142.24
